# %%
import pandas as pd

df = pd.read_csv('../../../data/tabiturient/all/programs.csv')
df
# Out:
#                                                direction  \
# 0                                               Биология
# 1                    Информационные системы и технологии
# 2                         Теплоэнергетика и теплотехника
# 3                     Электроэнергетика и электротехника
# 4                  Технологические машины и оборудование
# ...                                                  ...
# 19153                         Экономическая безопасность
# 19154              Искусство концертного исполнительства
# 19155  Художественное руководство оперно-симфонически...
# 19156                   Музыкально-театральное искусство
# 19157                                           Живопись
#
#                                                  profile program_code  \
# 0                                           Охотоведение     06.03.01
# 1      Управление аграрными проектами в области инфор...     09.03.02
# ...

# %%
# Выбираем строки, где хотя бы в одном столбце присутствует NaN
nan_rows = df[df.isnull().any(axis=1)]
# nan_rows

# %%
df['faculty'] = df['faculty'].fillna("no data")

# %%
nan_rows = df[df.isnull().any(axis=1)]
# nan_rows

# %%
df[df['forms'] == '[]']
# Out:
#                                       direction  \
# 311                                   Экономика
# 382                                   Экономика
# 509                                   Экономика
# 938    Фундаментальная и прикладная лингвистика
# 1216                                  Экономика
# ...                                         ...
# 19017                                Менеджмент
# 19061               Эксплуатация железных дорог
# 19132          Народная художественная культура
# 19140                                    Дизайн
# 19146              Искусство костюма и текстиля
#
#                                                  profile  \
# 311                Цифровая экономика и бизнес-аналитика
# 382                                    Мировая экономика
# 509                                  Экономика и финансы
# 938               Теоретическая и прикладная лингвистика
# 1216                 Экономика предприятий и организаций
# ...

# %%
df_vuz = pd.read_csv('../../../data/tabiturient/processed_data/vuz_all_cleaned.csv')

# %%
set(df_vuz['long_name'].unique()) - set(df['vuz'].unique())
# Out:
# {'Cмоленский государственный институт искусств',
#  'Великолукский филиал Петербургского государственного университета путей сообщения Императора Александра I',
#  'Институт пищевых технологий и дизайна (филиал) Нижегородского государственного инженерно-экономического университета',
#  'Липецкий казачий государственный институт технологий и управления - филиал Московского государственного университета технологий и управления им. К.Г. Разумовского',
#  'Пермский государственный медицинский университет им. академика Е. А. Вагнера',
#  'Пермский институт железнодорожного транспорта (филиал) Уральского государственного университета путей сообщения',
#  'Санкт-Петербургский государственный электротехнический университет «ЛЭТИ» им. В.И. Ульянова (Ленина)',
#  'Сергиево-Посадский филиал Всероссийского государственного института кинематографии им. С.А. Герасимова',
# ...

# %%
set(df['vuz'].unique()) - set(df_vuz['long_name'].unique())
# Out:
# {' HR-менеджмент',
#  ' IT-специалист для бизнеса',
#  ' Web-ориентированные информационно-аналитические системы',
#  ' Автоматизация технологических процессов и производств в нефтегазопереработке',
#  ' Аграрно-правовой профиль',
#  ' Аналитическая химия',
#  ' Антидопинговое обеспечение в спорте',
#  ' Архитектурно-строительное проектирование и др.',
#  ' Архитектурное проектирование (АЖОЗ)',
#  ' Аэродинамика ракет и космических транспортных систем',
#  ' Аэродромы',
#  ' Безопасность в чрезвычайных ситуациях',
#  ' Безопасность жизнедеятельности в техносфере',
#  ' Безопасность информационных систем',
#  ' Бизнеспроцессы полиграфического и упаковочного производства',
#  ' Биоинжиниринг живых систем',
#  ' Биоинформатика',
#  ' Бионический дизайн и др.',
#  ' Биотехнология',
#  ' Биоэкология',
#  ' Болезни непродуктивных животных',
#  ' Бухгалтерский учёт и контроль',
#  ' Ветеринарная фармация',
#  ' Взрывные технологии и утилизация боеприпасов',
# ...

# %%
df[df['vuz'] == 'День открытых дверей']
# Out:
#        direction                                            profile  \
# 17424  Экономика  Государственный финансовый контроль и цифровое...
#
#       program_code                   vuz               faculty  \
# 17424     38.03.01  День открытых дверей  Финансовый факультет
#
#                                           exams             scores  \
# 17424  [['РЯ'], ['M'], ['О', 'ИЯ', 'ИКТ', 'И']]  [['274', 'очно']]
#
#                                                    forms Unnamed: 8  \
# 17424  [{'education_form2': 'Очная', 'score': '274', ...        NaN
#
#       Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 17424        NaN         NaN         NaN         NaN         NaN

# %%
df[df['vuz'] == 'Сайт программы']
# Out:
#                           direction  \
# 10167              Сестринское дело
# 10168                 Лечебное дело
# 10169                     Педиатрия
# 10170                  Стоматология
# 10171  Медико-профилактическое дело
# ...                             ...
# 17450                        Туризм
# 17451              Гостиничное дело
# 17452                   Лингвистика
# 17453                     Философия
# 17454               Таможенное дело
#
#                                                  profile program_code  \
# 10167                                        Без профиля     34.03.01
# 10168                                        Без профиля     31.05.01
# 10169                                        Без профиля     31.05.02
# 10170                                        Без профиля     31.05.03
# 10171                                        Без профиля     32.05.01
# ...                                                  ...          ...
# ...

# %%
# df[df['vuz'] == 'Братский государственный университет']

# %%
df.iloc[1562]
# Out:
# direction                                                   Спорт
# profile                                        Танцевальный спорт
# program_code                                             49.03.04
# vuz             Волгоградская государственная академия физичес...
# faculty                             Факультет физической культуры
# exams                                     [['РЯ'], ['Б'], ['ДЭ']]
# scores                                           [['75', 'очно']]
# forms           [{'education_form2': 'Очная', 'score': '75', '...
# Unnamed: 8                                                    NaN
# Unnamed: 9                                                    NaN
# Unnamed: 10                                                   NaN
# Unnamed: 11                                                   NaN
# Unnamed: 12                                                   NaN
# Unnamed: 13                                                   NaN
# Name: 1562, dtype: object

# %%
df.drop(1391, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df[df['vuz'] == 'Сайт программы'].head(50)
# Out:
#                                                direction  \
# 10166                                   Сестринское дело
# 10167                                      Лечебное дело
# 10168                                          Педиатрия
# 10169                                       Стоматология
# 10170                       Медико-профилактическое дело
# 10171                             Клиническая психология
# 11095                                         Психология
# 11100         Государственное и муниципальное управление
# 11101                                 Бизнес-информатика
# 11102                                         Социология
# 11103                                  Социальная работа
# 11104                                      Юриспруденция
# 11105                                        Политология
# 11106                            Международные отношения
# 11107                  Реклама и связи с общественностью
# ...

# %%
df.iloc[10166:10172, df.columns.get_loc('vuz')] = 'Пермский государственный медицинский университет им. академика Е. А. Вагнера'
df.iloc[11095:11116, df.columns.get_loc('vuz')] = 'Северо-Западный институт управления РАНХиГС'
df.iloc[11868:11897, df.columns.get_loc('vuz')] = 'Российский биотехнологический университет'

# %%
df[df['vuz'] == 'Сайт программы'].head(50)
# Out:
#                                               direction  \
# 13839               Прикладная математика и информатика
# 13840              Информатика и вычислительная техника
# 13841              Информатика и вычислительная техника
# 13842               Информационные системы и технологии
# 13843                             Программная инженерия
# 13844                                      Радиотехника
# 13845                                      Радиотехника
# 13846   Инфокоммуникационные технологии и системы связи
# 13847  Конструирование и технология электронных средств
# 13848                     Электроника и наноэлектроника
# 13849                                   Приборостроение
# 13850               Биотехнические системы и технологии
# 13851                Электроэнергетика и электротехника
# 13852                       Мехатроника и робототехника
# 13853                         Техносферная безопасность
# 13854                              Управление качеством
# ...

# %%
df.iloc[13839:13865, df.columns.get_loc('vuz')] = 'Санкт-Петербургский государственный электротехнический университет «ЛЭТИ» им. В.И. Ульянова (Ленина)'

# %%
df[df['vuz'] == 'Сайт программы'].head(100)
# Out:
#                                         direction  \
# 17392         Прикладная математика и информатика
# 17393             Математика и компьютерные науки
# 17394                      Прикладная информатика
# 17395                      Прикладная информатика
# 17397                      Прикладная информатика
# 17398                       Программная инженерия
# 17400                 Информационная безопасность
# 17401                                  Инноватика
# 17402                                  Психология
# 17403                                   Экономика
# 17404                                   Экономика
# 17405                                   Экономика
# 17406                                   Экономика
# 17407                                   Экономика
# 17408                                   Экономика
# 17409                                   Экономика
# 17410                                   Экономика
# 17411                                   Экономика
# ...

# %%
# df.iloc[13839:17454, df.columns.get_loc('vuz')] = 'Финансовый Университет при Правительстве Российской Федерации'

# %%
df[df['vuz'] == 'Сайт программы'].head(100)
# Out:
#                                         direction  \
# 17392         Прикладная математика и информатика
# 17393             Математика и компьютерные науки
# 17394                      Прикладная информатика
# 17395                      Прикладная информатика
# 17397                      Прикладная информатика
# 17398                       Программная инженерия
# 17400                 Информационная безопасность
# 17401                                  Инноватика
# 17402                                  Психология
# 17403                                   Экономика
# 17404                                   Экономика
# 17405                                   Экономика
# 17406                                   Экономика
# 17407                                   Экономика
# 17408                                   Экономика
# 17409                                   Экономика
# 17410                                   Экономика
# 17411                                   Экономика
# ...

# %%
df.loc[df['vuz'] == 'Сайт программы', 'vuz'] = 'Финансовый Университет при Правительстве Российской Федерации'

# %%
df[df['vuz'] == 'Сайт программы'].head(100)
# Out:
# Empty DataFrame
# Columns: [direction, profile, program_code, vuz, faculty, exams, scores, forms, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13]
# Index: []

# %%
df.loc[df['vuz'] == 'День открытых дверей', 'vuz'] = 'Финансовый Университет при Правительстве Российской Федерации'

# %%
df[df['vuz'] == 'День открытых дверей']
# Out:
# Empty DataFrame
# Columns: [direction, profile, program_code, vuz, faculty, exams, scores, forms, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13]
# Index: []

# %%
df = df.replace('?', 'NEW')

# %%
df.to_csv('../../../data/tabiturient/processed_data/programs_cleaned.csv', index=False, encoding='utf-8')

# %%
df.iloc[76]
# Out:
# direction                   Музыкально-инструментальное искусство
# profile                                                      Баян
# program_code                                            Аккордеон
# vuz                                 Струнные щипковые инструменты
# faculty                                                  53.03.02
# exams           Арктический государственный институт культуры ...
# scores                             Кафедра музыкального искусства
# forms                                     [['РЯ'], ['Л'], ['ДЭ']]
# Unnamed: 8                                      [['137', 'очно']]
# Unnamed: 9      [{'education_form2': 'Очная', 'score': '137', ...
# Unnamed: 10                                                   NaN
# Unnamed: 11                                                   NaN
# Unnamed: 12                                                   NaN
# Unnamed: 13                                                   NaN
# Name: 76, dtype: object

# %%
df_vuz.iloc[76]
# Out:
# long_name          Кубанский казачий государственный институт пищ...
# short_name         Кубанский казачий институт пищевой индустрии и...
# geolocation                                       Краснодарский край
# is_goverment                                                       1
# rating                                                            -1
# logo                        https://tabiturient.ru/logovuz/mgutu.png
# website                                  https://www.темрюк-мгуту.рф
# phone_admission                                                   []
# phone_general                                                     []
# email_general                                                     []
# email_admission                                                   []
# comment                                                          NaN
# Name: 76, dtype: object

# %%
df = pd.read_csv('../../../data/tabiturient/processed_data/programs_cleaned.csv')

# %%
df.iloc[76]
# Out:
# direction                   Музыкально-инструментальное искусство
# profile            Баян; Аккордеон; Струнные щипковые инструменты
# program_code                                             53.03.02
# vuz             Арктический государственный институт культуры ...
# faculty                            Кафедра музыкального искусства
# exams                                     [['РЯ'], ['Л'], ['ДЭ']]
# scores                                          [['137', 'очно']]
# forms           [{'education_form2': 'Очная', 'score': '137', ...
# Name: 76, dtype: object

# %%
df = df.replace('?', 'NEW')

# %%
df.to_csv('../../../data/tabiturient/processed_data/programs_cleaned.csv', index=False, encoding='utf-8')

# %%
df.iloc[17488]
# Out:
# direction                                           Строительство
# profile         Автомобильные дороги и мосты; Промышленное и г...
# program_code                                             08.03.01
# vuz             Филиал Воронежского государственного техническ...
# faculty                                     Кафедра строительства
# exams                 [['РЯ'], ['М'], ['ИКТ', 'Ф'], ['', 'очно']]
# scores                                                         []
# forms           [{'education_form2': 'Очная', 'score': 'NEW', ...
# Name: 17488, dtype: object

# %%
df = df.replace(r'\?', 'NEW', regex=True)

# %%
df.to_csv('../../../data/tabiturient/processed_data/programs_cleaned.csv', index=False, encoding='utf-8')
