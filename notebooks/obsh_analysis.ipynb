# %%
import pandas as pd

df = pd.read_csv('osbh_all.csv')
df
# Out:
#      Unnamed: 0                                                vuz   obsh  \
# 0             0        Институт пищевых технологий и дизайна НГИЭУ  False
# 1             1  Институт сферы обслуживания и предпринимательс...  False
# 2             2          Институт технологий ДГТУ в г. Волгодонске  False
# 3             3  Институт ядерной энергетики СПбПУ в г. Сосновы...  False
# 4             4                                             ИрГУПС   True
# ..          ...                                                ...    ...
# 793         194                                               ЯГТИ   True
# 794         195                                               ЯГТУ   True
# 795         196                                               ЯрГУ   True
# 796         197                           Ярославский филиал ПГУПС   True
# 797         198         Ярославский филиал ФУ при Правительстве РФ  False
#
#                                                   info  rating
# ...

# %%
df['info'].isna().sum()
# Out:
# 650

# %%
df['rating'].isna().sum()
# Out:
# 718

# %%
df2 = pd.read_csv('vuz_all_cleaned.csv')
merged_df = pd.concat([df2, df], axis=1)
merged_df
# Out:
#      Unnamed: 0                                          long_name  \
# 0             0  Институт пищевых технологий и дизайна (филиал)...
# 1             1  Институт сферы обслуживания и предпринимательс...
# 2             2  Институт технологий (филиал) Донского государс...
# 3             3  Институт ядерной энергетики (филиал) Cанкт-Пет...
# 4             4  Иркутский государственный университет путей со...
# ..          ...                                                ...
# 793         194   Ярославский государственный театральный институт
# 794         195  Ярославский государственный технический универ...
# 795         196  Ярославский государственный университет им. П....
# 796         197  Ярославский филиал Петербургского государствен...
# 797         198  Ярославский филиал Финансового Университета пр...
#
#                                             short_name  \
# 0          Институт пищевых технологий и дизайна НГИЭУ
# ...

# %%
df = merged_df.drop('Unnamed: 0', axis=1)
df
# Out:
#                                              long_name  \
# 0    Институт пищевых технологий и дизайна (филиал)...
# 1    Институт сферы обслуживания и предпринимательс...
# 2    Институт технологий (филиал) Донского государс...
# 3    Институт ядерной энергетики (филиал) Cанкт-Пет...
# 4    Иркутский государственный университет путей со...
# ..                                                 ...
# 793   Ярославский государственный театральный институт
# 794  Ярославский государственный технический универ...
# 795  Ярославский государственный университет им. П....
# 796  Ярославский филиал Петербургского государствен...
# 797  Ярославский филиал Финансового Университета пр...
#
#                                             short_name  \
# 0          Институт пищевых технологий и дизайна НГИЭУ
# 1    Институт сферы обслуживания и предпринимательс...
# 2            Институт технологий ДГТУ в г. Волгодонске
# 3    Институт ядерной энергетики СПбПУ в г. Сосновы...
# ...

# %%
df.to_csv('vuz_all_cleaned_w_obsh.csv', index=False, encoding='utf-8')
df.to_excel('vuzs.xlsx')
